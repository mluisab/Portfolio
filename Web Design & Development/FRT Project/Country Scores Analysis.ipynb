# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd

low_high=score.loc[[0,98]]
low_high=low_high.drop(columns=["Total Score"])
second=low_high.plot.bar(rot=0)
plt.title("Lowest versus Highest Scoring Countries")
plt.xlabel("China versus Syria")
plt.ylabel("Scores")
# Out:
# Text(0, 0.5, 'Scores')
